# %%
import bin_packing_generator as bpp

# %%
bpp.bin_packing_generator("dataset/bin_packing_dataset.json")
# print(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 bpp.bin_packing_generator("dataset/bin_packing_dataset.json")
#       2 # print(data)
#
# AttributeError: module 'bin_packing_generator' has no attribute 'bin_packing_generator'
